# %%
import matplotlib.pyplot as plt

# Data
platforms = ['Instagram', 'YouTube', 'X', 'Threads']
views = [1758, 980, 523, 382]

# Plot
plt.pie(views, labels=platforms, autopct='%1.1f%%')
plt.title('Video Views by Platform')
plt.show()
